# %% [markdown]
# # PANDAS

# %%
import pandas as pd

# %%
data= pd.read_csv ("covid-variants.csv")
data
# Out:
#         location        date         variant  num_sequences  perc_sequences  \
# 0         Angola  2020-07-06           Alpha              0             0.0
# 1         Angola  2020-07-06       B.1.1.277              0             0.0
# 2         Angola  2020-07-06       B.1.1.302              0             0.0
# 3         Angola  2020-07-06       B.1.1.519              0             0.0
# 4         Angola  2020-07-06         B.1.160              0             0.0
# ...          ...         ...             ...            ...             ...
# 100411  Zimbabwe  2021-11-01         Omicron              0             0.0
# 100412  Zimbabwe  2021-11-01   S:677H.Robin1              0             0.0
# 100413  Zimbabwe  2021-11-01  S:677P.Pelican              0             0.0
# 100414  Zimbabwe  2021-11-01          others              0             0.0
# 100415  Zimbabwe  2021-11-01         non_who              0             0.0
#
#         num_sequences_total
# ...

# %% [markdown]
# # DISPLAY TOP 10 DATASET

# %%
data.head(n=10)
# Out:
#   location        date    variant  num_sequences  perc_sequences  \
# 0   Angola  2020-07-06      Alpha              0             0.0
# 1   Angola  2020-07-06  B.1.1.277              0             0.0
# 2   Angola  2020-07-06  B.1.1.302              0             0.0
# 3   Angola  2020-07-06  B.1.1.519              0             0.0
# 4   Angola  2020-07-06    B.1.160              0             0.0
# 5   Angola  2020-07-06    B.1.177              0             0.0
# 6   Angola  2020-07-06    B.1.221              0             0.0
# 7   Angola  2020-07-06    B.1.258              0             0.0
# 8   Angola  2020-07-06    B.1.367              0             0.0
# 9   Angola  2020-07-06    B.1.620              0             0.0
#
#    num_sequences_total
# 0                    3
# 1                    3
# 2                    3
# 3                    3
# 4                    3
# 5                    3
# 6                    3
# 7                    3
# 8                    3
# ...

# %% [markdown]
# # DISPLAY LAST 10 DATASET

# %%
data.tail(n=10)
# Out:
#         location        date         variant  num_sequences  perc_sequences  \
# 100406  Zimbabwe  2021-11-01           Gamma              0             0.0
# 100407  Zimbabwe  2021-11-01            Iota              0             0.0
# 100408  Zimbabwe  2021-11-01           Kappa              0             0.0
# 100409  Zimbabwe  2021-11-01          Lambda              0             0.0
# 100410  Zimbabwe  2021-11-01              Mu              0             0.0
# 100411  Zimbabwe  2021-11-01         Omicron              0             0.0
# 100412  Zimbabwe  2021-11-01   S:677H.Robin1              0             0.0
# 100413  Zimbabwe  2021-11-01  S:677P.Pelican              0             0.0
# 100414  Zimbabwe  2021-11-01          others              0             0.0
# 100415  Zimbabwe  2021-11-01         non_who              0             0.0
#
#         num_sequences_total
# 100406                    6
# 100407                    6
# 100408                    6
# ...

# %% [markdown]
# # DISPLAY TOTAL ROWS AND COLUMNS

# %%
data.shape
# Out:
# (100416, 6)

# %% [markdown]
# # DISPLAY COLUMNS

# %%
data.columns
# Out:
# Index(['location', 'date', 'variant', 'num_sequences', 'perc_sequences',
#        'num_sequences_total'],
#       dtype='object')

# %% [markdown]
# # LOC LABEL BASE   ILOC INTEGAR BASE

# %%
data.loc[data.date=="2021-11-01"]
# Out:
#          location        date         variant  num_sequences  perc_sequences  \
# 1608    Argentina  2021-11-01           Alpha             10            1.81
# 1609    Argentina  2021-11-01       B.1.1.277              0            0.00
# 1610    Argentina  2021-11-01       B.1.1.302              0            0.00
# 1611    Argentina  2021-11-01       B.1.1.519              0            0.00
# 1612    Argentina  2021-11-01         B.1.160              0            0.00
# ...           ...         ...             ...            ...             ...
# 100411   Zimbabwe  2021-11-01         Omicron              0            0.00
# 100412   Zimbabwe  2021-11-01   S:677H.Robin1              0            0.00
# 100413   Zimbabwe  2021-11-01  S:677P.Pelican              0            0.00
# 100414   Zimbabwe  2021-11-01          others              0            0.00
# 100415   Zimbabwe  2021-11-01         non_who              0            0.00
#
#         num_sequences_total
# ...

# %% [markdown]
# # CHECK THE DATE AND VARIANT COLUMNS

# %%
data.loc[(data.date=="2021-11-01") & (data["variant"]=="B.1.1.277")]
# Out:
#               location        date    variant  num_sequences  perc_sequences  \
# 1609         Argentina  2021-11-01  B.1.1.277              0             0.0
# 3265         Australia  2021-11-01  B.1.1.277              0             0.0
# 4321           Austria  2021-11-01  B.1.1.277              0             0.0
# 5065           Bahrain  2021-11-01  B.1.1.277              0             0.0
# 6049        Bangladesh  2021-11-01  B.1.1.277              0             0.0
# ...                ...         ...        ...            ...             ...
# 94993          Ukraine  2021-11-01  B.1.1.277              0             0.0
# 96625   United Kingdom  2021-11-01  B.1.1.277              0             0.0
# 97705    United States  2021-11-01  B.1.1.277              0             0.0
# 98809          Vietnam  2021-11-01  B.1.1.277              0             0.0
# 100393        Zimbabwe  2021-11-01  B.1.1.277              0             0.0
#
#         num_sequences_total
# ...

# %%
data.loc[(data.date=="2021-11-01") | (data["variant"]=="B.1.1.277")]
# Out:
#         location        date         variant  num_sequences  perc_sequences  \
# 1         Angola  2020-07-06       B.1.1.277              0             0.0
# 25        Angola  2020-08-31       B.1.1.277              0             0.0
# 49        Angola  2020-09-28       B.1.1.277              0             0.0
# 73        Angola  2020-10-12       B.1.1.277              0             0.0
# 97        Angola  2020-10-26       B.1.1.277              0             0.0
# ...          ...         ...             ...            ...             ...
# 100411  Zimbabwe  2021-11-01         Omicron              0             0.0
# 100412  Zimbabwe  2021-11-01   S:677H.Robin1              0             0.0
# 100413  Zimbabwe  2021-11-01  S:677P.Pelican              0             0.0
# 100414  Zimbabwe  2021-11-01          others              0             0.0
# 100415  Zimbabwe  2021-11-01         non_who              0             0.0
#
#         num_sequences_total
# ...

# %% [markdown]
# # check not null value in dataset

# %%
data.notnull().sum()
# Out:
# location               100416
# date                   100416
# variant                100416
# num_sequences          100416
# perc_sequences         100416
# num_sequences_total    100416
# dtype: int64

# %% [markdown]
# # check null value in dataset

# %%
data.isnull().sum()
# Out:
# location               0
# date                   0
# variant                0
# num_sequences          0
# perc_sequences         0
# num_sequences_total    0
# dtype: int64

# %% [markdown]
# # how to check greater num of sequence

# %%
data.loc[(data.num_sequences_total>=500)]
# Out:
#         location        date         variant  num_sequences  perc_sequences  \
# 1608   Argentina  2021-11-01           Alpha             10            1.81
# 1609   Argentina  2021-11-01       B.1.1.277              0            0.00
# 1610   Argentina  2021-11-01       B.1.1.302              0            0.00
# 1611   Argentina  2021-11-01       B.1.1.519              0            0.00
# 1612   Argentina  2021-11-01         B.1.160              0            0.00
# ...          ...         ...             ...            ...             ...
# 98731    Vietnam  2021-09-06         Omicron              0            0.00
# 98732    Vietnam  2021-09-06   S:677H.Robin1              0            0.00
# 98733    Vietnam  2021-09-06  S:677P.Pelican              0            0.00
# 98734    Vietnam  2021-09-06          others              0            0.00
# 98735    Vietnam  2021-09-06         non_who              0            0.00
#
#        num_sequences_total
# 1608                   553
# ...

# %% [markdown]
# # check the multiple columns

# %%
data.loc[(data.variant=="B.1.160"),["location"]]
# Out:
#         location
# 4         Angola
# 28        Angola
# 52        Angola
# 76        Angola
# 100       Angola
# ...          ...
# 100300  Zimbabwe
# 100324  Zimbabwe
# 100348  Zimbabwe
# 100372  Zimbabwe
# 100396  Zimbabwe
#
# [4184 rows x 1 columns]

# %%
data.loc[(data.variant=="B.1.160"),["location","date"]]
# Out:
#         location        date
# 4         Angola  2020-07-06
# 28        Angola  2020-08-31
# 52        Angola  2020-09-28
# 76        Angola  2020-10-12
# 100       Angola  2020-10-26
# ...          ...         ...
# 100300  Zimbabwe  2021-09-06
# 100324  Zimbabwe  2021-09-20
# 100348  Zimbabwe  2021-10-04
# 100372  Zimbabwe  2021-10-18
# 100396  Zimbabwe  2021-11-01
#
# [4184 rows x 2 columns]

# %% [markdown]
# # ILOC integer base  how to check 4,52 row

# %%
data.iloc[[100396,28]]
# Out:
#         location        date  variant  num_sequences  perc_sequences  \
# 100396  Zimbabwe  2021-11-01  B.1.160              0             0.0
# 28        Angola  2020-08-31  B.1.160              0             0.0
#
#         num_sequences_total
# 100396                    6
# 28                        1

# %%
data.iloc[[76,48],0:3]
# Out:
#    location        date  variant
# 76   Angola  2020-10-12  B.1.160
# 48   Angola  2020-09-28    Alpha

# %% [markdown]
# # #how to check first 3 row in iloc

# %%
data.iloc[0:3]
# Out:
#   location        date    variant  num_sequences  perc_sequences  \
# 0   Angola  2020-07-06      Alpha              0             0.0
# 1   Angola  2020-07-06  B.1.1.277              0             0.0
# 2   Angola  2020-07-06  B.1.1.302              0             0.0
#
#    num_sequences_total
# 0                    3
# 1                    3
# 2                    3

# %% [markdown]
# # how to delete last columns

# %%
data.iloc[0:3,:-1]
# Out:
#   location        date    variant  num_sequences  perc_sequences
# 0   Angola  2020-07-06      Alpha              0             0.0
# 1   Angola  2020-07-06  B.1.1.277              0             0.0
# 2   Angola  2020-07-06  B.1.1.302              0             0.0

# %% [markdown]
# # ##how to use describle() in pandas

# %%
data.describe()
# Out:
#        num_sequences  perc_sequences  num_sequences_total
# count  100416.000000   100416.000000        100416.000000
# mean       72.171676        6.154355          1509.582457
# std      1669.262169       21.898989          8445.291772
# min         0.000000       -0.010000             1.000000
# 25%         0.000000        0.000000            12.000000
# 50%         0.000000        0.000000            59.000000
# 75%         0.000000        0.000000           394.000000
# max    142280.000000      100.000000        146170.000000

# %% [markdown]
# # ONE HOT ENCODING
